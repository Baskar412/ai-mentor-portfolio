# %% [markdown]
# <a href="https://colab.research.google.com/github/Baskar412/ai-mentor-portfolio/blob/main/Day9_StudyAgent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q langgraph langchain-google-genai langchain-community duckduckgo-search

import os, getpass
if 'GEMINI_API_KEY' not in os.environ:
    os.environ['GEMINI_API_KEY'] = getpass.getpass('Gemini API key: ')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 kB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 29.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 23.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 43.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 4.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# Gemini API key: ··········

# %%
pip install -U ddgs
# Out:
# Collecting ddgs
#   Downloading ddgs-9.14.4-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from ddgs) (8.4.0)
# Requirement already satisfied: primp>=1.2.3 in /usr/local/lib/python3.12/dist-packages (from ddgs) (1.3.1)
# Requirement already satisfied: lxml>=4.9.4 in /usr/local/lib/python3.12/dist-packages (from ddgs) (6.1.1)
# Requirement already satisfied: httpx>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (0.28.1)
# Collecting fake-useragent>=2.2.0 (from ddgs)
#   Downloading fake_useragent-2.2.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (3.15)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (0.16.0)
# Requirement already satisfied: brotli in /usr/local/lib/python3.12/dist-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.2.0)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.12/dist-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.3.0)
# Collecting socksio==1.* (from httpx[brotli,http2,socks]>=0.28.1->ddgs)
#   Downloading socksio-1.0.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.1.0)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.15.0)
# Downloading ddgs-9.14.4-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 2.5 MB/s eta 0:00:00
# Downloading fake_useragent-2.2.0-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 6.9 MB/s eta 0:00:00
# Downloading socksio-1.0.0-py3-none-any.whl (12 kB)
# Installing collected packages: socksio, fake-useragent, ddgs
# Successfully installed ddgs-9.14.4 fake-useragent-2.2.0 socksio-1.0.0

# %%
from langchain_core.tools import tool
from langchain_community.tools import DuckDuckGoSearchRun

search = DuckDuckGoSearchRun()

@tool
def web_search(query: str) -> str:
    """Search the web for up-to-date information."""
    return search.run(query)

result = web_search.invoke("TCS hiring 2026")
print(result[:500])
# Out:
# February 25, 2026 - TCS will conduct the hiring round using the TCS iON platform rather than the TCS Community platform, which TCS has utilized in the past. Yes, students from 2024 can apply in this drive. January 20, 2026 - Tata Consultancy Services (TCS), India’s most trusted IT services company, has launched its TCS Hiring 2026 drive, creating a massive wave of job opportunities for freshers and experienced professionals across the country. April 13, 2026 - India's largest IT services firm, T

# %%
from langchain_core.tools import tool
from langchain_community.tools import DuckDuckGoSearchRun

@tool
def web_search(query: str) -> str:
    """Search the web for up-to-date information.
    Use when the question requires current events, recent facts, or
    information not in static training knowledge."""
    return DuckDuckGoSearchRun().run(query)

# Test the tool directly
print(web_search.invoke({'query': 'TCS hiring 2026'})[:400])
# Out:
# February 25, 2026 - TCS will conduct the hiring round using the TCS iON platform rather than the TCS Community platform, which TCS has utilized in the past. Yes, students from 2024 can apply in this drive. January 20, 2026 - Tata Consultancy Services (TCS), India’s most trusted IT services company, has launched its TCS Hiring 2026 drive, creating a massive wave of job opportunities for freshers an

# %%
from langgraph.prebuilt import create_react_agent
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model='gemini-2.5-flash')
agent = create_react_agent(llm, tools=[web_search])

print('Agent created.')
# Out:
# Agent created.
# /tmp/ipykernel_1303/1070485237.py:5: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agent = create_react_agent(llm, tools=[web_search])

# %%
result = agent.invoke({
    'messages': [('user', "What is TCS's 2026 hiring quota?")]
})

# Print every message in the conversation
for i, m in enumerate(result['messages']):
    print(f'\n[{i}] {type(m).__name__}')
    if hasattr(m, 'content'):
        print(f'    Content: {str(m.content)[:300]}')
    if hasattr(m, 'tool_calls') and m.tool_calls:
        print(f'    Tool calls: {m.tool_calls}')
# Out:
# [0] HumanMessage
#     Content: What is TCS's 2026 hiring quota?
#
# [1] AIMessage
#     Content:
#     Tool calls: [{'name': 'web_search', 'args': {'query': 'TCS 2026 hiring quota'}, 'id': '1e5c065a-60b2-4e83-be1c-b76cd664f5c0', 'type': 'tool_call'}]
#
# [2] ToolMessage
#     Content: Tata Consultancy Services (TCS), India's leading information technology company, has already offered jobs to 25,000 fresh graduates for the financial year 2027 (FY27). How to Apply for TCS NQT 2026? All interested and eligible candidates can register online before 14 June 2026 through the official T
#
# [3] AIMessage
#     Content: [{'type': 'text', 'text': "I'm sorry, but I could not find a specific hiring quota for TCS for the year 2026 in my search results. I found information about job offers for FY27 and registration for TCS NQT 2026, but no explicit hiring quota for 2026.", 'extras': {'signature': 'Cr4EAQw51sc3Rg3//mhheJ

# %%
result = agent.invoke({
    'messages': [('user', 'Search this URL and tell me what it says: https://this-domain-does-not-exist-12345.example.com/jd')]
})

# Watch how the agent recovers
for i, m in enumerate(result['messages']):
    print(f'\n[{i}] {type(m).__name__}')
    if hasattr(m, 'content'):
        print(f'    {str(m.content)[:300]}')
# Out:
# [0] HumanMessage
#     Search this URL and tell me what it says: https://this-domain-does-not-exist-12345.example.com/jd
#
# [1] AIMessage
#     [{'type': 'text', 'text': 'I am sorry, I cannot directly access the content of a URL. My `web_search` tool is designed to search the web for information, not to browse specific URLs. Additionally, the URL you provided appears to be a non-existent domain.', 'extras': {'signature': 'CqEJAQw51scPu18uLY

# %%
import requests
from bs4 import BeautifulSoup
from langchain_core.tools import tool

@tool
def jd_fetcher(url: str) -> str:
    """Fetch a job description from a URL and return clean plain text.
    Use when the user provides a job posting URL and you need the JD content.
    Returns first 4000 characters of the cleaned page text."""
    try:
        r = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'}, timeout=10)
        r.raise_for_status()
        soup = BeautifulSoup(r.text, 'html.parser')
        for tag in soup(['script', 'style']):
            tag.decompose()
        return soup.get_text(separator='\n', strip=True)[:4000]
    except Exception as e:
        return f'ERROR: failed to fetch URL — {e}'

# %%
@tool
def skills_gap(student_skills: str, must_have_skills: str) -> str:
    """Compare a student's skills (comma-separated) to a job's must-have skills (comma-separated).
    Returns missing skills, comma-separated, or 'none' if student has all.
    Use when the user provides a student profile and a JD's required skills."""
    a = set(s.strip().lower() for s in student_skills.split(',') if s.strip())
    b = set(s.strip().lower() for s in must_have_skills.split(',') if s.strip())
    missing = sorted(b - a)
    return ', '.join(missing) if missing else 'none'

# Test
print(skills_gap.invoke({
    'student_skills': 'Python, Java, SQL',
    'must_have_skills': 'Python, Java, SQL, Spring Boot, AWS',
}))
# Expected: 'aws, spring boot'
# Out:
# aws, spring boot

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model='gemini-2.5-flash')

@tool
def answer_scorer(question: str, answer: str) -> str:
    """Score a student's answer to a placement interview question, 1-10, with one-line rationale.
    Use when evaluating how well a student answered a specific interview question.
    Returns format: 'Score: X/10. Rationale: <reason>'."""
    prompt = (f'Score this placement interview answer 1-10 with one-line rationale.\n'
              f'Question: {question}\n'
              f'Answer: {answer}')
    return llm.invoke(prompt).content

# Test
print(answer_scorer.invoke({
    'question': 'Why TCS Digital?',
    'answer': 'Because TCS is big and they pay well.',
}))
# Out:
# **Score: 2/10**
#
# **Rationale:** Extremely generic, shows no specific research into TCS Digital, and highlights extrinsic motivators (size, pay) which are a significant red flag for genuine interest and commitment.

# %%
from langgraph.prebuilt import create_react_agent

tools = [jd_fetcher, skills_gap, answer_scorer]
agent = create_react_agent(llm, tools=tools)
print(f'Agent created with {len(tools)} tools.')
# Out:
# Agent created with 3 tools.
# /tmp/ipykernel_1303/3943891205.py:4: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agent = create_react_agent(llm, tools=tools)

# %%
import json
import pathlib

profiles = json.loads(
    pathlib.Path('/content/student_profiles_json_sample.json').read_text()
)

for i, p in enumerate(profiles):

    print(f'\n{"="*70}')
    print(
        f'Student {i+1}: '
        f'{p.get("name")} — '
        f'{p.get("branch")} '
        f'CGPA {p.get("cgpa")} '
        f'→ {p.get("target_company")}'
    )
    print(f'{"="*70}')

    msg = f"""
I am {p.get('name')}, pursuing B.Tech in {p.get('branch')}.

CGPA: {p.get('cgpa')}

Skills:
{', '.join(p.get('skills', []))}

Target company:
{p.get('target_company')}

Please:
1. Ask 3 mock interview questions tailored to my profile.
2. Provide one sample answer and score it out of 10.
3. Suggest missing technical skills I should learn to become a strong fit.
"""

    try:
        result = agent.invoke(
            {'messages': [('user', msg)]},
            config={'recursion_limit': 10}
        )

    except Exception as e:
        print(f"\nAgent failed: {e}")
        continue

    for j, m in enumerate(result['messages']):

        print(f'\n  [{j}] {type(m).__name__}')

        if getattr(m, 'content', None):
            print("      CONTENT:")
            print(f'      {str(m.content)[:500]}')

        if getattr(m, 'tool_calls', None):
            print("      TOOL CALLS:")
            for tc in m.tool_calls:
                print(
                    f'      → {tc.get("name")}({tc.get("args")})'
                )
# Out:
# ======================================================================
# Student 1: Aarav Sharma — None CGPA 8.7 → None
# ======================================================================
#
#   [0] HumanMessage
#       CONTENT:
#
# I am Aarav Sharma, pursuing B.Tech in None.
#
# CGPA: 8.7
#
# Skills:
# Python, JavaScript, SQL
#
# Target company:
# None
#
# Please:
# 1. Ask 3 mock interview questions tailored to my profile.
# 2. Provide one sample answer and score it out of 10.
# 3. Suggest missing technical skills I should learn to become a strong fit.
#
#
#   [1] AIMessage
#       CONTENT:
#       [{'type': 'text', 'text': 'Hello Aarav! Based on your profile (B.Tech, CGPA 8.7, Skills: Python, JavaScript, SQL), here are 3 mock interview questions:\n\n1.  **Python:** Explain the difference between a list and a tuple in Python. When would you choose one over the other?\n2.  **JavaScript:** Describe the event loop in JavaScript and how it handles asynchronous operations.\n3.  **SQL:** Given a database table named \'Orders\' with columns \'OrderID\', \'CustomerID\', \'OrderDate\', and \'TotalA
#
# ======================================================================
# Student 2: Sneha Reddy — None CGPA 9.1 → None
# ======================================================================
#
#   [0] HumanMessage
#       CONTENT:
#
# I am Sneha Reddy, pursuing B.Tech in None.
#
# CGPA: 9.1
#
# Skills:
# Embedded Systems, C++, IoT
#
# Target company:
# None
#
# Please:
# 1. Ask 3 mock interview questions tailored to my profile.
# 2. Provide one sample answer and score it out of 10.
# 3. Suggest missing technical skills I should learn to become a strong fit.
#
#
#   [1] AIMessage
#       CONTENT:
#       [{'type': 'text', 'text': 'Here are 3 mock interview questions tailored to your profile:\n\n1.  Can you explain the main differences between a microcontroller and a microprocessor, and in what scenarios would you choose one over the other in an embedded system design?\n2.  Describe a project where you utilized C++ in an embedded systems context. What specific C++ features did you find most useful, and what challenges did you encounter regarding resource management or real-time constraints?\n3.
#
# ======================================================================
# Student 3: Rahul Verma — None CGPA 8.4 → None
# ======================================================================
#
#   [0] HumanMessage
#       CONTENT:
#
# I am Rahul Verma, pursuing B.Tech in None.
#
# CGPA: 8.4
#
# Skills:
# Machine Learning, Pandas, Data Visualization
#
# Target company:
# None
#
# Please:
# 1. Ask 3 mock interview questions tailored to my profile.
# 2. Provide one sample answer and score it out of 10.
# 3. Suggest missing technical skills I should learn to become a strong fit.
#
#
#   [1] AIMessage
#       CONTENT:
#       [{'type': 'text', 'text': 'Hello Rahul! It\'s great to know your profile: B.Tech with a CGPA of 8.4 and skills in Machine Learning, Pandas, and Data Visualization.\n\nTo provide you with the most tailored mock interview questions and specific suggestions for missing technical skills to become a "strong fit," I need to know your target company or the type of job role you are aiming for (e.g., Data Scientist, Machine Learning Engineer, Data Analyst).\n\nIn the meantime, here are 3 general mock int
#       TOOL CALLS:
#       → answer_scorer({'question': 'Can you explain the concept of overfitting and how to mitigate it in machine learning?', 'answer': "Overfitting occurs when a machine learning model learns the training data too well, capturing noise and specific patterns that don't generalize to new, unseen data. This leads to high performance on the training set but poor performance on the test set. To mitigate overfitting, techniques like cross-validation can be used to get a more robust estimate of model performance. Regularization methods, such as L1 or L2 regularization, penalize large coefficients, discouraging complex models. Early stopping during training can prevent the model from learning too much from the training data. Feature selection can reduce the number of irrelevant features. Finally, increasing the amount of training data can help the model learn more general patterns."})
#
#   [2] ToolMessage
#       CONTENT:
#       10/10 - Excellent, comprehensive explanation that clearly defines overfitting and provides a strong, diverse list of effective mitigation strategies.
#
#   [3] AIMessage
#       CONTENT:
#       Here are 3 mock interview questions tailored to your profile:
#
# 1.  "Can you explain the concept of overfitting and how to mitigate it in machine learning?"
# 2.  "Describe a time you used Pandas to solve a data manipulation problem. What was the problem, and how did Pandas help you address it?"
# 3.  "Imagine you're given a dataset and asked to create a visualization. What steps would you take to ensure your visualization is effective and communicates insights clearly?"
#
# Here's a sample answer to th

# %%
result = agent.invoke({
    'messages': [('user', 'Fetch this JD and tell me the must-have skills: '
                          'https://this-does-not-exist-99999.example.com/jd')]
}, config={'recursion_limit': 5})

print('Failure recovery trace:')
for j, m in enumerate(result['messages']):
    print(f'\n[{j}] {type(m).__name__}')
    if hasattr(m, 'content') and m.content:
        print(f'    {str(m.content)[:300]}')
    if hasattr(m, 'tool_calls') and m.tool_calls:
        for tc in m.tool_calls:
            print(f'    → {tc.get("name")}({tc.get("args")})')
# Out:
# Failure recovery trace:
#
# [0] HumanMessage
#     Fetch this JD and tell me the must-have skills: https://this-does-not-exist-99999.example.com/jd
#
# [1] AIMessage
#     → jd_fetcher({'url': 'https://this-does-not-exist-99999.example.com/jd'})
#
# [2] ToolMessage
#     ERROR: failed to fetch URL — HTTPSConnectionPool(host='this-does-not-exist-99999.example.com', port=443): Max retries exceeded with url: /jd (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7bf3c762d8b0>: Failed to resolve 'this-does-not-exist-99999.example.com' ([Errn
#
# [3] AIMessage
#     I was unable to fetch the job description from the provided URL. Please check the URL and try again. I can only fetch the JD, I cannot tell you the must-have skills from it.
