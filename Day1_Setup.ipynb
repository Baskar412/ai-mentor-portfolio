# %% [markdown]
# <a href="https://colab.research.google.com/github/Baskar412/ai-mentor-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the progressive levels of AI proficiency, from basic understanding to advanced development:
#
# *   **Foundation (AI Literacy):** The broadest base, focusing on fundamental understanding of AI concepts, capabilities, limitations, and ethical implications, relevant for everyone.
# *   **Application (AI User):** Progresses to effectively using AI tools and applications for specific tasks, involving skills like prompt engineering and leveraging AI for productivity.
# *   **Integration (AI Implementer):** Involves customizing, deploying, and integrating existing AI models or APIs into broader systems and workflows.
# *   **Development (AI Engineer):** Focuses on building, training, and deploying AI/ML models from scratch, requiring deep technical skills in data science, algorithms, and programming.
# *   **Innovation (AI Researcher):** The apex, dedicated to pushing the boundaries of AI through theoretical research, developing novel algorithms, and advancing the field.
